# %% [markdown]
# # Project 1
#
# In this first project you will create a framework to scope out data science projects. This framework will provide you with a guide to develop a well-articulated problem statement and analysis plan that will be robust and reproducible.

# %% [markdown]
# ### Read and evaluate the following problem statement:
# Determine which free-tier customers will covert to paying customers, using demographic data collected at signup (age, gender, location, and profession) and customer useage data (days since last log in, and activity score 1 = active user, 0= inactive user) based on Hooli data from Jan-Apr 2015.

# %% [markdown]
# #### 1. What is the outcome?

# %% [markdown]
# Answer: Shows which free tier customers will convert to paying customers

# %% [markdown]
# #### 2. What are the predictors/covariates?

# %% [markdown]
# Answer:
# * Customer Demographic Data: Age, Gender, Location & Professions and;
# * Customer Usage Data: Days since log in & activity score.

# %% [markdown]
# #### 3. What timeframe is this data relevent for?

# %% [markdown]
# Answer: January 2015 - April 2015

# %% [markdown]
# #### 4. What is the hypothesis?

# %% [markdown]
# Answer: Customers who logged in most recently and have an activity score of 1 are more likely to convert from free-tier customers to paying customers

# %% [markdown]
# ## Let's get started with our dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
admission_data = pd.read_csv('../assets/admissions.csv')

# %%
admission_data.head()
# Out:
#    admit    gre   gpa  prestige
# 0      0  380.0  3.61       3.0
# 1      1  660.0  3.67       3.0
# 2      1  800.0  4.00       1.0
# 3      1  640.0  3.19       4.0
# 4      0  520.0  2.93       4.0

# %% [markdown]
# #### 1. Create a data dictionary

# %%
admission_data.sort_values(by='gre')
# Out:
#      admit    gre   gpa  prestige
# 304      0  220.0  2.83       3.0
# 179      0  300.0  3.01       3.0
# 71       0  300.0  2.92       4.0
# 315      1  300.0  2.84       2.0
# 216      0  340.0  2.90       1.0
# 316      1  340.0  3.00       2.0
# 100      0  340.0  3.15       3.0
# 119      0  340.0  2.92       3.0
# 17       0  360.0  2.56       3.0
# 281      0  360.0  3.27       3.0
# 112      0  360.0  3.00       3.0
# 34       0  360.0  3.14       1.0
# 102      0  380.0  3.33       4.0
# 265      0  380.0  3.34       3.0
# 83       0  380.0  2.91       4.0
# 145      0  380.0  3.43       3.0
# 232      0  380.0  3.38       2.0
# 193      0  380.0  3.59       4.0
# 57       0  380.0  2.94       3.0
# 0        0  380.0  3.61       3.0
# 302      1  400.0  3.15       2.0
# 348      0  400.0  3.36       2.0
# 151      0  400.0  3.38       2.0
# 108      0  400.0  2.93       3.0
# 7        0  400.0  3.08       2.0
# 58       0  400.0  3.65       2.0
# ...

# %%
admission_data.sort_values(by='gpa')
# Out:
#      admit    gre   gpa  prestige
# 289      0  420.0  2.26       4.0
# 40       0  560.0  2.42       2.0
# 372      1  680.0  2.42       1.0
# 48       0  440.0  2.48       4.0
# 156      0  560.0  2.52       2.0
# 294      0  480.0  2.55       1.0
# 17       0  360.0  2.56       3.0
# 176      0  520.0  2.62       2.0
# 384      1  480.0  2.62       2.0
# 397      0  460.0  2.63       2.0
# 341      1  560.0  2.65       3.0
# 121      1  480.0  2.67       2.0
# 233      0  420.0  2.67       3.0
# 39       1  520.0  2.68       3.0
# 323      0  420.0  2.69       2.0
# 324      0  520.0  2.70       3.0
# 379      0  540.0  2.70       2.0
# 82       0  500.0  2.71       2.0
# 147      0  560.0  2.71       3.0
# 163      0  520.0  2.73       2.0
# 240      0  440.0  2.76       2.0
# 291      0  800.0  2.78       2.0
# 365      0  480.0  2.78       3.0
# 184      0  500.0  2.79       4.0
# 131      0  640.0  2.79       2.0
# 269      0  500.0  2.81       3.0
# ...

# %%
admission_data.sort_values(by='prestige')
# Out:
#      admit    gre   gpa  prestige
# 126      1  600.0  3.54       1.0
# 234      1  800.0  3.53       1.0
# 338      0  540.0  3.20       1.0
# 113      0  600.0  3.22       1.0
# 217      1  460.0  3.64       1.0
# 106      1  700.0  3.56       1.0
# 91       1  720.0  3.64       1.0
# 88       0  700.0  3.28       1.0
# 241      1  520.0  3.81       1.0
# 79       1  620.0  4.00       1.0
# 118      1  800.0  3.70       1.0
# 78       0  540.0  3.12       1.0
# 357      0  720.0  3.31       1.0
# 360      1  520.0  4.00       1.0
# 69       0  800.0  3.73       1.0
# 68       0  580.0  3.69       1.0
# 67       0  620.0  3.30       1.0
# 361      1  540.0  3.49       1.0
# 364      1  560.0  3.36       1.0
# 244      0  540.0  3.04       1.0
# 368      0  580.0  4.00       1.0
# 355      1  760.0  2.81       1.0
# 372      1  680.0  2.42       1.0
# 335      1  620.0  3.71       1.0
# 325      0  680.0  3.90       1.0
# 216      0  340.0  2.90       1.0
# ...

# %% [markdown]
# Answer:
#
# Variable | Description | Type of Variable
# ---| ---| ---
# Admit | 0 = Not Admitted 1 = Admitted | categorical
# gre | 220 - 800 | continuous
# gpa | 2.26 - 4.00 | continuous
# prestige | 1-not prestigious 2-somewhat prestiguous 3-prestigous 4-very prestigous | categorical

# %% [markdown]
# We would like to explore the association between X and Y

# %% [markdown]
# #### 2. What is the outcome?

# %% [markdown]
# Answer: Shows who will be admitted

# %% [markdown]
# #### 3. What are the predictors/covariates?

# %% [markdown]
# Answer: GRE score, GPA, and level of prestige

# %% [markdown]
# #### 4. What timeframe is this data relevent for?

# %% [markdown]
# Answer: There is not clear details on the timeframe in which the dataset was taken

# %% [markdown]
# #### 4. What is the hypothesis?

# %% [markdown]
# Answer: If you have are at a high level of prestige, a high GPA and high GRE score you have a higher likeihood of being admitted.

# %% [markdown]
#     Using the above information, write a well-formed problem statement.

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# ### Exploratory Analysis Plan

# %% [markdown]
# Using the lab from a class as a guide, create an exploratory analysis plan.

# %% [markdown]
# #### 1. What are the goals of the exploratory analysis?

# %% [markdown]
# Answer:

# %% [markdown]
# #### 2a. What are the assumptions of the distribution of data?

# %% [markdown]
# Answer:

# %% [markdown]
# #### 2b. How will determine the distribution of your data?

# %% [markdown]
# Answer:

# %% [markdown]
# #### 3a. How might outliers impact your analysis?

# %% [markdown]
# Answer:

# %% [markdown]
# #### 3b. How will you test for outliers?

# %% [markdown]
# Answer:

# %% [markdown]
# #### 4a. What is colinearity?

# %% [markdown]
# Answer:

# %% [markdown]
# #### 4b. How will you test for colinearity?

# %% [markdown]
# Answer:

# %% [markdown]
# #### 5. What is your exploratory analysis plan?
# Using the above information, write an exploratory analysis plan that would allow you or a colleague to reproduce your analysis 1 year from now.

# %% [markdown]
# Answer:

# %% [markdown]
# ## Bonus Questions:
# 1. Outline your analysis method for predicting your outcome
# 2. Write an alternative problem statement for your dataset
# 3. Articulate the assumptions and risks of the alternative model
